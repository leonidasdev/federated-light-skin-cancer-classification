# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from PIL import Image

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. HAM10000 Dataset
#
# Human Against Machine with 10000 training images.

# %%
# TODO: Load HAM10000 metadata
# data_dir = Path('../data/ham10000')
# metadata = pd.read_csv(data_dir / 'HAM10000_metadata.csv')
# metadata.head()

# %%
# TODO: Class distribution analysis
# plt.figure(figsize=(10, 6))
# metadata['dx'].value_counts().plot(kind='bar')
# plt.title('HAM10000 Class Distribution')
# plt.xlabel('Diagnosis')
# plt.ylabel('Count')
# plt.show()

# %% [markdown]
# ## 2. Sample Images

# %%
# TODO: Display sample images from each class
# fig, axes = plt.subplots(2, 4, figsize=(16, 8))
# for idx, class_name in enumerate(metadata['dx'].unique()):
#     sample = metadata[metadata['dx'] == class_name].iloc[0]
#     img_path = data_dir / 'images' / f"{sample['image_id']}.jpg"
#     img = Image.open(img_path)
#     ax = axes[idx // 4, idx % 4]
#     ax.imshow(img)
#     ax.set_title(class_name)
#     ax.axis('off')
# plt.tight_layout()

# %% [markdown]
# ## 3. Data Quality Analysis

# %%
# TODO: Check for missing values, duplicates, image dimensions
