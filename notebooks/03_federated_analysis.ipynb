# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from src.utils.visualization import plot_federated_rounds, plot_data_distribution

# %matplotlib inline

# %% [markdown]
# ## 1. Data Distribution Across Clients

# %%
# TODO: Visualize data distribution across clients
# IID vs Non-IID comparison

# %% [markdown]
# ## 2. Training Convergence

# %%
# TODO: Plot global model convergence across rounds

# %% [markdown]
# ## 3. Centralized vs Federated Comparison

# %%
# TODO: Compare centralized and federated learning results

# %% [markdown]
# ## 4. Communication Efficiency

# %%
# TODO: Analyze communication costs
